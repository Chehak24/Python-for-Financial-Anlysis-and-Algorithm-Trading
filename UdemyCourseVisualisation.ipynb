# %% [markdown]
# # MATPLOT VISUALISATION

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x=np.linspace(0,5,11)
y=x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
## functional method
plt.plot(x,y)
plt.show() ##this command prints the plot instead of showing the plot

# %%
plt.plot(x,y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
### object oriented method
fig = plt.figure()

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,0.8,0.8])

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x,y)

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,0.8,0.8]) ##0.1->left, 0.1->bottom, 0.8->length, 0.8->breadth

axes.plot(x,y)
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.4,0.3])

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.4,0.15,0.4,0.3])

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.4,0.3])
axes1.plot(x,y)
axes1.set_title('LARGER PLOT')
axes2.plot(y,x)
axes2.set_title('SMALLER PLOT')
# Out:
# Text(0.5, 1.0, 'SMALLER PLOT')

# %% [markdown]
# ### SUBPLOTS

# %%
fig,axes=plt.subplots()

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
#axes.plot(x,y)

# %%
fig,axes=plt.subplots(nrows=3,ncols=3)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
for current_ax in axes :
    current_ax.plot(x,y)

# %%
type(axes) ##its an array, u ca iterate thru it
# Out:
# numpy.ndarray

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y)
axes[1].plot(y,x)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y)
axes[0].set_title('First Plot')
axes[1].plot(y,x)
axes[1].set_title('Second Plot')

plt.tight_layout()  ##to avoid overlapping
# Out:
# Text(0.5, 1.0, 'Second Plot')

# %% [markdown]
# ### Figure Size and DPI

# %%
fig = plt.figure(figsize=(3,2))
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig = plt.figure(figsize=(3,2),dpi=1000)
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,axes=plt.subplots(nrows=2,ncols=1,figsize=(8,2))
axes[0].plot(x,y)
axes[1].plot(y,x)
plt.tight_layout()

# %%
fig.savefig('my_pic.jpeg',dpi=200)

# %%
fig = plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_title('Title')
ax.set_ylabel('Y')
ax.set_xlabel('X')
# Out:
# Text(0.5, 0, 'X')

# %%
fig = plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.plot(y,x)

# %%
fig = plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='X squared')
ax.plot(x,x**3,label = 'X cubed')
ax.legend()

# %%
fig = plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='X squared')
ax.plot(x,x**3,label = 'X cubed')
ax.legend(loc=10) ## different location codes arefixed

# %%
fig = plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='X squared')
ax.plot(x,x**3,label = 'X cubed')
ax.legend(loc=(0.1,0.1)) ## or use a tuple

# %% [markdown]
# ### Plot Appearance

# %%
fig = plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='pink')

# %%
## rgb hexcodes
fig = plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='#FF8C00')

# %%
##LINE WIDTH AND LINE STYLE
fig = plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='purple',linewidth=10,alpha = 150) ## alpa maintains the visibility

# %%
fig = plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='purple',lw=10,linestyle='--')

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
len(x)
# Out:
# 11

# %%
fig = plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='purple',linewidth=3,marker='o',markersize=9,markerfacecolor='yellow',markeredgewidth=5,markeredgecolor='green')

# %%
# fig = plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='purple',linewidth=3)
ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# <ipython-input-73-81b1af932599>:2: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=fig.add_axes([0,0,1,1])
# (0.0, 2.0)

# %% [markdown]
# ### check main file

# %% [markdown]
# ### exercise

# %%
import numpy as np
x=np.arange(0,100)
y=x*2
z=x**2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

 ### plt.show()  if not in jupyter

# %%
fig =plt.figure()

ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
fig = plt.figure()

ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.2,0.5,0.2,0.2])

# %%
fig = plt.figure()

ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.2,0.5,0.2,0.2])

ax1.plot(x,y,color='red')
ax2.plot(y,x,color='red')

# %%
fig=plt.figure()

ax=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.2,0.5,0.4,0.4])

##large
ax.plot(x,z)
ax.set_xlabel('X')
ax.set_ylabel('Z')

##Insert
ax2.plot(x,y)
ax2.set_title('zoom')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_xlim([20,22])
ax2.set_ylim([30,50])
# Out:
# (30.0, 50.0)

# %%
fig,axes=plt.subplots(1,2)
axes[0].plot(x,y,color='blue',ls='--')
axes[1].plot(x,z,color='red',lw=3)

# %%
fig,axes=plt.subplots(1,2,figsize=(12,2))
axes[0].plot(x,y,color='blue',ls='--')
axes[1].plot(x,z,color='red',lw=3)

# %% [markdown]
# # PANDAS VISUALISATION

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
import seaborn as sns

# %%
df1 = pd.read_csv('df1',index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
df1['A'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
df1['A'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['A'].plot(kind='hist',bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.area()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df3=df1.head()

# %%
df3
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df3.plot.line(x=df3.index,y='B')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-122-260f023fd342> in <module>
# ----> 1 df3.plot.line(x=df3.index,y='B')
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in line(self, x, y, **kwargs)
#    1021         as coordinates.
#    1022         """
# -> 1023         return self(kind="line", x=x, y=y, **kwargs)
#    1024
#    1025     @Appender(
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     918                 if is_integer(x) and not data.columns.holds_integer():
#     919                     x = data_cols[x]
# --> 920                 elif not isinstance(data[x], ABCSeries):
#     921                     raise ValueError("x must be a label or position")
#     922                 data = data.set_index(x)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
# ...

# %%
df1.plot.scatter(x='A',y='B',c='C') ## column C is depicted thru color
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']) ## depicting column C thru size
# Out:
# C:\Users\cheha\anaconda3\lib\site-packages\matplotlib\collections.py:922: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*100)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
df=pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])

# %%
df.plot.hexbin(x='a',y='b',gridsize=25)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df2['a'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2['a'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
mcdon =pd.read_csv('mcdonalds.csv',index_col='Date',parse_dates=True)
mcdon.head()
# Out:
#             Adj. Close  Adj. Volume
# Date
# 1970-01-02    0.209761    2825604.0
# 1970-01-05    0.213316    2210449.5
# 1970-01-06    0.214501    1951168.5
# 1970-01-07    0.213316    2728768.5
# 1970-01-08    0.213316    2242404.0

# %%
mcdon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 11993 entries, 1970-01-02 to 2017-07-14
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Adj. Close   11993 non-null  float64
#  1   Adj. Volume  11993 non-null  float64
# dtypes: float64(2)
# memory usage: 281.1 KB

# %%
mcdon['Adj. Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
mcdon['Adj. Volume'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
mcdon['Adj. Close'].plot(xlim=['2007-01-01','2009-01-01'])
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
mcdon['Adj. Close'].plot(xlim=['2007-01-01','2009-01-01'],ylim=(20,50))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import matplotlib.dates as dates
mcdon['Adj. Close'].plot(xlim=['2007-01-01','2009-01-01'],ylim=(0,50))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
idx=mcdon.index

# %%
idx
# Out:
# DatetimeIndex(['1970-01-02', '1970-01-05', '1970-01-06', '1970-01-07',
#                '1970-01-08', '1970-01-09', '1970-01-12', '1970-01-13',
#                '1970-01-14', '1970-01-15',
#                ...
#                '2017-06-30', '2017-07-03', '2017-07-05', '2017-07-06',
#                '2017-07-07', '2017-07-10', '2017-07-11', '2017-07-12',
#                '2017-07-13', '2017-07-14'],
#               dtype='datetime64[ns]', name='Date', length=11993, freq=None)

# %%
idx=mcdon.loc['2007-01-01':'2007-05-01'].index

# %%
idx
# Out:
# DatetimeIndex(['2007-01-03', '2007-01-04', '2007-01-05', '2007-01-08',
#                '2007-01-09', '2007-01-10', '2007-01-11', '2007-01-12',
#                '2007-01-16', '2007-01-17', '2007-01-18', '2007-01-19',
#                '2007-01-22', '2007-01-23', '2007-01-24', '2007-01-25',
#                '2007-01-26', '2007-01-29', '2007-01-30', '2007-01-31',
#                '2007-02-01', '2007-02-02', '2007-02-05', '2007-02-06',
#                '2007-02-07', '2007-02-08', '2007-02-09', '2007-02-12',
#                '2007-02-13', '2007-02-14', '2007-02-15', '2007-02-16',
#                '2007-02-20', '2007-02-21', '2007-02-22', '2007-02-23',
#                '2007-02-26', '2007-02-27', '2007-02-28', '2007-03-01',
#                '2007-03-02', '2007-03-05', '2007-03-06', '2007-03-07',
#                '2007-03-08', '2007-03-09', '2007-03-12', '2007-03-13',
#                '2007-03-14', '2007-03-15', '2007-03-16', '2007-03-19',
# ...

# %%
stock=mcdon.loc['2007-01-01':'2007-05-01']['Adj. Close']

# %%
stock
# Out:
# Date
# 2007-01-03    31.662754
# 2007-01-04    31.424580
# 2007-01-05    31.424580
# 2007-01-08    31.547276
# 2007-01-09    31.605015
#                 ...
# 2007-04-25    35.098239
# 2007-04-26    35.531283
# 2007-04-27    35.329196
# 2007-04-30    34.845630
# 2007-05-01    35.466327
# Name: Adj. Close, Length: 82, dtype: float64

# %%
fig,ax=plt.subplots()
ax.plot_date(idx,stock,'-')
fig.autofmt_xdate()

# %%
fig,ax=plt.subplots()
ax.plot_date(idx,stock,'-')

ax.yaxis.grid(True)

fig.autofmt_xdate()

# %%
fig,ax=plt.subplots()
ax.plot_date(idx,stock,'-')

## Locating

ax.xaxis.set_major_locator(dates.MonthLocator())

ax.xaxis.set_major_formatter(dates.DateFormatter('%b-%y'))
fig.autofmt_xdate()

# %%
fig,ax=plt.subplots()
ax.plot_date(idx,stock,'-')

## Locating

ax.xaxis.set_major_locator(dates.MonthLocator())

ax.xaxis.set_major_formatter(dates.DateFormatter('%b---%y'))
fig.autofmt_xdate()

# %%
fig,ax=plt.subplots()
ax.plot_date(idx,stock,'-')

## Locating

ax.xaxis.set_major_locator(dates.MonthLocator())
##formatting
ax.xaxis.set_major_formatter(dates.DateFormatter('\n \n %b-%y'))
fig.autofmt_xdate()

# %%
fig,ax=plt.subplots()
ax.plot_date(idx,stock,'-')

ax.xaxis.set_major_locator(dates.MonthLocator())
ax.xaxis.set_major_formatter(dates.DateFormatter('\n \n\n %b-%y'))

ax.xaxis.set_minor_locator(dates.WeekdayLocator())
ax.xaxis.set_minor_formatter(dates.DateFormatter('%d'))

fig.autofmt_xdate()

# %%
fig,ax=plt.subplots()
ax.plot_date(idx,stock,'-')

ax.xaxis.set_major_locator(dates.MonthLocator())
ax.xaxis.set_major_formatter(dates.DateFormatter('\n \n\n %b-%y'))

ax.xaxis.set_minor_locator(dates.WeekdayLocator(byweekday=0))
ax.xaxis.set_minor_formatter(dates.DateFormatter('%a'))

fig.autofmt_xdate()

# %% [markdown]
# ### exercise

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df3=pd.read_csv('df3')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3.plot.scatter(x='a',y='b',figsize=(12,2),s=50,c='red')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df3['a'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('ggplot')

# %%
df3['a'].plot.hist(bins=20,alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df3[['a','b']].plot.box()
# Out:
# <AxesSubplot:>

# %%
df3['d'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df3['d'].plot.kde(lw=5,ls='--')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df3.i[0:30]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-175-be7b701904e9> in <module>
# ----> 1 df3.ix[0:30]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'
